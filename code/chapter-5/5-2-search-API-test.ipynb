# %% [markdown]
# # 5. 주소 데이터 API를 활용한 주소 검색 웹 서버 구축
#
# - 작성자: 박예준
# - 작성일자: 2024-02-26

# %% [markdown]
# ## 5-2. API로 데이터 호출하기

# %% [markdown]
# ### requests 모듈을 이용한 API 데이터 호출

# %%
# !pip3 install requests

# %%
import requests
keyword = '정부세종청사' #검색 키워드
url = "https://business.juso.go.kr/addrlink/addrLinkApi.do"
params = {
    "confmKey":"발급받은 API 승인KEY",
    "currentPage":"1",
    "countPerPage":"10",
    "keyword": keyword,
    "resultType":"json"
}
result = requests.get(url, params=params)
result.json()

# %%
result.json()
# Out:
# {'results': {'common': {'errorMessage': '정상',
#    'countPerPage': '10',
#    'totalCount': '8',
#    'errorCode': '0',
#    'currentPage': '1'},
#   'juso': [{'detBdNmList': '행정안전부동, 한국정책방송원동, 소방청동',
#     'engAddr': '13 Jeongbu 2cheongsa-ro, Sejong-si',
#     'rn': '정부2청사로',
#     'emdNm': '나성동',
#     'zipNo': '30128',
#     'roadAddrPart2': ' (나성동)',
#     'emdNo': '01',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 나성동 772 정부세종2청사',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 정부2청사로 13',
#     'bdNm': '정부세종2청사',
#     'admCd': '3611010700',
#     'udrtYn': '0',
#     'lnbrMnnm': '772',
#     'roadAddr': '세종특별자치시 정부2청사로 13 (나성동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '13',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103351287',
#     'mtYn': '0',
#     'bdMgtSn': '3611010700104680000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '',
#     'engAddr': '455 Galmae-ro, Sejong-si',
#     'rn': '갈매로',
#     'emdNm': '어진동',
#     'zipNo': '30110',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '02',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 558 정부세종청사 주차1동(지하주차장)',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 갈매로 455',
#     'bdNm': '정부세종청사 주차1동(지하주차장)',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '558',
#     'roadAddr': '세종특별자치시 갈매로 455 (어진동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '455',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103258073',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105580000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '',
#     'engAddr': '25 Doum 2-ro, Sejong-si',
#     'rn': '도움2로',
#     'emdNm': '어진동',
#     'zipNo': '30117',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '02',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 580 정부세종청사 주차3동(지하주차장)',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 도움2로 25',
#     'bdNm': '정부세종청사 주차3동(지하주차장)',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '580',
#     'roadAddr': '세종특별자치시 도움2로 25 (어진동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '25',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103258081',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105800000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '',
#     'engAddr': '34 Doum 6-ro, Sejong-si',
#     'rn': '도움6로',
#     'emdNm': '어진동',
#     'zipNo': '30112',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '02',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 563 정부세종청사 주차2동(지하주차장)',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 도움6로 34',
#     'bdNm': '정부세종청사 주차2동(지하주차장)',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '563',
#     'roadAddr': '세종특별자치시 도움6로 34 (어진동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '34',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103258085',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105630000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '민원동, 업무동',
#     'engAddr': '42 Doum 6-ro, Sejong-si',
#     'rn': '도움6로',
#     'emdNm': '어진동',
#     'zipNo': '30112',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '02',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 572 정부세종청사 중앙동',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 도움6로 42',
#     'bdNm': '정부세종청사 중앙동',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '572',
#     'roadAddr': '세종특별자치시 도움6로 42 (어진동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '42',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103258085',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105720000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '수영장, 풋살장, 다목적홀',
#     'engAddr': '11-10 Doum 8-ro, Sejong-si',
#     'rn': '도움8로',
#     'emdNm': '어진동',
#     'zipNo': '30103',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '01',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 552-1 정부세종청사 체육관',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 도움8로 11-10',
#     'bdNm': '정부세종청사 체육관',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '552',
#     'roadAddr': '세종특별자치시 도움8로 11-10 (어진동)',
#     'lnbrSlno': '1',
#     'buldMnnm': '11',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103258087',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105520000000001',
#     'buldSlno': '10'},
#    {'detBdNmList': '정부세종청사 고속시외버스정류장',
#     'engAddr': '456 Hannuri-daero, Sejong-si',
#     'rn': '한누리대로',
#     'emdNm': '어진동',
#     'zipNo': '30113',
#     'roadAddrPart2': ' (어진동)',
#     'emdNo': '01',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 어진동 561-1 정부세종청사 고속시외버스정류장',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 한누리대로 456',
#     'bdNm': '정부세종청사 고속시외버스정류장',
#     'admCd': '3611011000',
#     'udrtYn': '0',
#     'lnbrMnnm': '561',
#     'roadAddr': '세종특별자치시 한누리대로 456 (어진동)',
#     'lnbrSlno': '1',
#     'buldMnnm': '456',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361102000002',
#     'mtYn': '0',
#     'bdMgtSn': '3611011000105610000000001',
#     'buldSlno': '0'},
#    {'detBdNmList': '',
#     'engAddr': '10 Jeongbu 2cheongsa-ro, Sejong-si',
#     'rn': '정부2청사로',
#     'emdNm': '나성동',
#     'zipNo': '30129',
#     'roadAddrPart2': ' (나성동)',
#     'emdNo': '01',
#     'sggNm': '',
#     'jibunAddr': '세종특별자치시 나성동 779 에스엠타워',
#     'siNm': '세종특별자치시',
#     'roadAddrPart1': '세종특별자치시 정부2청사로 10',
#     'bdNm': '에스엠타워',
#     'admCd': '3611010700',
#     'udrtYn': '0',
#     'lnbrMnnm': '779',
#     'roadAddr': '세종특별자치시 정부2청사로 10 (나성동)',
#     'lnbrSlno': '0',
#     'buldMnnm': '10',
#     'bdKdcd': '0',
#     'liNm': '',
#     'rnMgtSn': '361103351287',
#     'mtYn': '0',
#     'bdMgtSn': '3611010700104940000000001',
#     'buldSlno': '0'}]}}
